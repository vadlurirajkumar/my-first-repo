# %% [markdown]
# <a href="https://colab.research.google.com/github/vadlurirajkumar/my-first-repo/blob/main/Download.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# // difference between hardware and software
#
# hardware are pysical components of an computer where software is uses hardware to work
#
# example for hardware are : RAM, CPU, GPU, Hard Drives
# example for softwares are : Windows OS, MS-Office, etc..,
